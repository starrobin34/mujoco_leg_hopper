# %%
# Standalone RL training cell for YOUR model (leg_hopper.xml)
# - TWO-DOF actuation: hip_motor + knee_motor controlled by the policy
# - Passive tendon spring: F = k*(L-L0) when L>L0 else 0
# - Reward = "best repeatable hop height": encourages multiple hops reaching similar apex height
#
# Requirements:
#   pip install mujoco gymnasium stable-baselines3 numpy imageio imageio-ffmpeg

import os
import numpy as np
import mujoco
import gymnasium as gym
from gymnasium import spaces

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor, VecVideoRecorder


# ------------------------- USER SETTINGS -------------------------
MODEL_XML_PATH = "leg_hopper.xml"

# Joint/actuator names in your XML
HIP_JOINT_NAME       = "hip_joint"
KNEE_JOINT_NAME      = "knee_joint"
HIP_MOTOR_NAME       = "hip_motor"
KNEE_MOTOR_NAME      = "knee_motor"
TENDON_NAME          = "leg_spring"
TENDON_ACT_NAME      = "leg_spring_actuator"

# Root slider joints (in your XML)
ROOT_X_JOINT_NAME    = "hip_linear_x"
ROOT_Z_JOINT_NAME    = "hip_linear_z"

# Tendon spring parameters (your values)
SPRING_K  = 500.0       # N/m
SPRING_L0 = 0.2109      # m

# Action scaling (must respect each actuator ctrlrange in XML)
# If ctrlrange for hip/knee is [-1, 1], keep these = 1.0.
MAX_HIP_CTRL  = 2.0
MAX_KNEE_CTRL = 2.0

# Env timing
SEED = 0
CTRL_HZ = 50
EPISODE_SECONDS = 3.0    # allow multiple hops

# Repeatable hop reward settings
APEX_WINDOW = 10            # how many recent hops define "repeatable height"
MIN_HOPS_FOR_SCORE = 2     # only start scoring after you have at least this many apex events
CONSISTENCY_W = 4.0        # penalty weight on hop-to-hop variation (higher = more consistent)
HEIGHT_W = 5.0             # reward weight on repeatable height per apex
FLIP_TERMINATE_ANGLE = 2.2 # rad, safety termination if hip joint goes crazy

# PPO
TOTAL_TIMESTEPS = 300_000
SAVE_PATH = "ppo_hip_knee_repeatable_hops.zip"

# Video recording
RECORD_VIDEO = True
VIDEO_DIR = "videos"
VIDEO_EVERY_N_STEPS = 50_000
VIDEO_SECONDS = 20.0
VIDEO_LENGTH = int(VIDEO_SECONDS * CTRL_HZ)

# ---------------------------------------------------------------


def _name2id_or_raise(model, obj_type, name: str) -> int:
    idx = mujoco.mj_name2id(model, obj_type, name)
    if idx < 0:
        raise ValueError(f"Name not found: {name} (type={obj_type})")
    return int(idx)

def _joint_qposadr(model, joint_id: int) -> int:
    return int(model.jnt_qposadr[joint_id])

def _joint_dofadr(model, joint_id: int) -> int:
    return int(model.jnt_dofadr[joint_id])


class HipKneeRepeatHopEnv(gym.Env):
    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 50}

    def __init__(
        self,
        xml_path: str,
        render_mode: str | None = None,
        episode_seconds: float = 3.0,
        ctrl_hz: int = 50,
        max_hip_ctrl: float = 1.0,
        max_knee_ctrl: float = 1.0,
        seed: int = 0,
    ):
        super().__init__()

        if not os.path.exists(xml_path):
            raise FileNotFoundError(f"MuJoCo XML not found: {xml_path}")

        self.model = mujoco.MjModel.from_xml_path(xml_path)
        self.data = mujoco.MjData(self.model)

        # IDs
        self.hip_jid   = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_JOINT, HIP_JOINT_NAME)
        self.knee_jid  = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_JOINT, KNEE_JOINT_NAME)
        self.rootx_jid = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_JOINT, ROOT_X_JOINT_NAME)
        self.rootz_jid = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_JOINT, ROOT_Z_JOINT_NAME)

        self.hip_aid   = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_ACTUATOR, HIP_MOTOR_NAME)
        self.knee_aid  = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_ACTUATOR, KNEE_MOTOR_NAME)

        self.tendon_id  = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_TENDON, TENDON_NAME)
        self.tendon_aid = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_ACTUATOR, TENDON_ACT_NAME)
        
        self.track_body_id = mujoco.mj_name2id(self.model, mujoco.mjtObj.mjOBJ_BODY, "hip_linear_guide")

        # Addresses
        self.hip_qpos_adr   = _joint_qposadr(self.model, self.hip_jid)
        self.hip_dof_adr    = _joint_dofadr(self.model, self.hip_jid)
        self.knee_qpos_adr  = _joint_qposadr(self.model, self.knee_jid)
        self.knee_dof_adr   = _joint_dofadr(self.model, self.knee_jid)
        self.rootz_qpos_adr = _joint_qposadr(self.model, self.rootz_jid)
        self.rootz_dof_adr  = _joint_dofadr(self.model, self.rootz_jid)

        # Timing
        self.episode_seconds = float(episode_seconds)
        self.ctrl_hz = int(ctrl_hz)
        self.ctrl_dt = 1.0 / self.ctrl_hz
        self.sim_dt = float(self.model.opt.timestep)
        self.substeps = max(1, int(round(self.ctrl_dt / self.sim_dt)))

        self.max_hip_ctrl  = float(max_hip_ctrl)
        self.max_knee_ctrl = float(max_knee_ctrl)
        self.render_mode = render_mode
        self.np_random, _ = gym.utils.seeding.np_random(seed)

        self.horizon_steps = int(round(self.episode_seconds * self.ctrl_hz))
        self.t = 0

        # Hop bookkeeping
        self._prev_vz = 0.0
        self._apex_heights = []

        # Spaces
        # obs: [hip_q, hip_qd, knee_q, knee_qd, root_z, root_vz, tendon_L, ncon, phase]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(9,), dtype=np.float32)

        # action: [hip_u, knee_u] in [-1, 1] each (scaled by MAX_*_CTRL)
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(2,), dtype=np.float32)

        # Rendering (rgb_array)
        self._renderer = None

    # ------------------ state helpers ------------------
    def _get_root_z_vz(self) -> tuple[float, float]:
        z  = float(self.data.qpos[self.rootz_qpos_adr])
        vz = float(self.data.qvel[self.rootz_dof_adr])
        return z, vz

    def _get_knee_q_qd(self) -> tuple[float, float]:
        return float(self.data.qpos[self.knee_qpos_adr]), float(self.data.qvel[self.knee_dof_adr])

    def _get_hip_q_qd(self) -> tuple[float, float]:
        return float(self.data.qpos[self.hip_qpos_adr]), float(self.data.qvel[self.hip_dof_adr])

    def _get_tendon_length(self) -> float:
        return float(self.data.ten_length[self.tendon_id])

    def _get_obs(self) -> np.ndarray:
        hip_q, hip_qd = self._get_hip_q_qd()
        knee_q, knee_qd = self._get_knee_q_qd()
        z, vz = self._get_root_z_vz()
        L = self._get_tendon_length()
        ncon = float(self.data.ncon)
        phase = float(self.t) / float(max(1, self.horizon_steps))
        return np.array([hip_q, hip_qd, knee_q, knee_qd, z, vz, L, ncon, phase], dtype=np.float32)

    # ------------------ tendon spring ------------------
    def _apply_tendon_spring_force(self):
        L = float(self.data.ten_length[self.tendon_id])
        F = SPRING_K * (L - SPRING_L0) if L > SPRING_L0 else 0.0
        self.data.ctrl[self.tendon_aid] = float(F)
        return L, float(F)

    # ------------------ hop event detection ------------------
    def _detect_apex_event(self, z: float, vz: float, ncon: int) -> bool:
        apex = (ncon == 0) and (self._prev_vz > 0.0) and (vz <= 0.0)
        self._prev_vz = vz
        if apex:
            self._apex_heights.append(z)
        return apex

    def _repeatable_height_score(self) -> tuple[float, float]:
        if len(self._apex_heights) < MIN_HOPS_FOR_SCORE:
            return 0.0, 0.0
        recent = self._apex_heights[-APEX_WINDOW:]
        repeatable_h = float(np.min(recent))
        std_recent = float(np.std(recent)) if len(recent) >= 2 else 0.0
        return repeatable_h, std_recent

    # ------------------ gym API ------------------
    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        if seed is not None:
            self.np_random, _ = gym.utils.seeding.np_random(seed)

        mujoco.mj_resetData(self.model, self.data)

        # Root start
        self.data.qpos[self.rootz_qpos_adr] = 0.0
        self.data.qvel[self.rootz_dof_adr]  = 0.0

        # Small randomization on both joints (helps robustness)
        self.data.qpos[self.hip_qpos_adr]  += self.np_random.uniform(-0.05, 0.05)
        self.data.qvel[self.hip_dof_adr]   += self.np_random.uniform(-0.2, 0.2)
        self.data.qpos[self.knee_qpos_adr] += self.np_random.uniform(-0.05, 0.05)
        self.data.qvel[self.knee_dof_adr]  += self.np_random.uniform(-0.2, 0.2)

        mujoco.mj_forward(self.model, self.data)

        self.t = 0
        _, vz = self._get_root_z_vz()
        self._prev_vz = vz
        self._apex_heights = []

        return self._get_obs(), {}

    def step(self, action):
        self.t += 1
        self.data.ctrl[:] = 0.0

        # Tendon spring
        L, F = self._apply_tendon_spring_force()

        # Policy actions
        hip_u  = float(np.clip(action[0], -1.0, 1.0)) * self.max_hip_ctrl
        knee_u = float(np.clip(action[1], -1.0, 1.0)) * self.max_knee_ctrl

        self.data.ctrl[self.hip_aid]  = hip_u
        self.data.ctrl[self.knee_aid] = knee_u

        # Physics
        for _ in range(self.substeps):
            mujoco.mj_step(self.model, self.data)

        # State
        z, vz = self._get_root_z_vz()
        ncon = int(self.data.ncon)

        # Reward shaping
        reward = 0.02 * float(z)

        apex = self._detect_apex_event(z, vz, ncon)
        repeatable_h, std_recent = self._repeatable_height_score()

        if apex and len(self._apex_heights) >= MIN_HOPS_FOR_SCORE:
            reward += HEIGHT_W * repeatable_h
            reward -= CONSISTENCY_W * std_recent

        # Control penalty (both joints)
        reward -= 1e-2 * (hip_u * hip_u + knee_u * knee_u)

        # Termination / truncation
        truncated = (self.t >= self.horizon_steps)
        terminated = False

        # Safety: NaNs or extreme fall
        if not np.isfinite(z) or not np.isfinite(vz):
            terminated = True
        if z < -1.5:
            terminated = True

        # Extra safety: hip joint shouldn't blow up
        hip_q, _ = self._get_hip_q_qd()
        if abs(hip_q) > FLIP_TERMINATE_ANGLE:
            terminated = True

        info = {
            "root_z": z,
            "root_vz": vz,
            "tendon_L": L,
            "tendon_F": F,
            "hip_u": hip_u,
            "knee_u": knee_u,
            "ncon": ncon,
            "apex": bool(apex),
            "apex_count": len(self._apex_heights),
            "repeatable_h": repeatable_h,
            "std_recent": std_recent,
            "apex_heights": self._apex_heights.copy(),
        }

        return self._get_obs(), float(reward), terminated, truncated, info

    # ---- Rendering for VecVideoRecorder ----
    def render(self):
        if self.render_mode is None:
            return None
        if self.render_mode == "rgb_array":
            if self._renderer is None:
                self._renderer = mujoco.Renderer(self.model, height=480, width=640)
            self._renderer.update_scene(self.data, camera="close_cam")
            return self._renderer.render()
        if self.render_mode == "human":
            return None
        raise ValueError(f"Unknown render_mode: {self.render_mode}")

    def close(self):
        if self._renderer is not None:
            try:
                self._renderer.close()
            except Exception:
                pass
            self._renderer = None


# -------------------- Sanity check --------------------
def sanity_check(xml_path: str, steps: int = 300):
    print("=== SANITY CHECK ===")
    env = HipKneeRepeatHopEnv(
        xml_path=xml_path,
        render_mode=None,
        episode_seconds=2.0,
        ctrl_hz=CTRL_HZ,
        max_hip_ctrl=MAX_HIP_CTRL,
        max_knee_ctrl=MAX_KNEE_CTRL,
        seed=SEED
    )
    obs, _ = env.reset(seed=SEED)

    # simple open-loop to verify signals remain sane
    f = 2.0
    A = 0.5
    for i in range(steps):
        t = i / CTRL_HZ
        hip_u  = A * np.sin(2*np.pi*f*t)
        knee_u = A * np.cos(2*np.pi*f*t)
        obs, rew, terminated, truncated, info = env.step(np.array([hip_u, knee_u], dtype=np.float32))

        if i % 50 == 0:
            print(
                f"step={i:4d} | z={info['root_z']:7.4f} | vz={info['root_vz']:7.4f} | "
                f"L={info['tendon_L']:7.4f} | F={info['tendon_F']:7.2f} | "
                f"hip_u={info['hip_u']:6.3f} | knee_u={info['knee_u']:6.3f} | ncon={info['ncon']} | "
                f"apex={int(info['apex'])} | apex_count={info['apex_count']} | repeatable_h={info['repeatable_h']:.4f}"
            )

        if terminated or truncated:
            break

    env.close()
    print("Sanity check done.\n")


def make_env(render_mode=None):
    return HipKneeRepeatHopEnv(
        xml_path=MODEL_XML_PATH,
        render_mode=render_mode,
        episode_seconds=EPISODE_SECONDS,
        ctrl_hz=CTRL_HZ,
        max_hip_ctrl=MAX_HIP_CTRL,
        max_knee_ctrl=MAX_KNEE_CTRL,
        seed=SEED,
    )


# -------------------- 1) Sanity check --------------------
sanity_check(MODEL_XML_PATH, steps=300)

# -------------------- 2) Vector env + video --------------------
base_env = DummyVecEnv([lambda: make_env(render_mode="rgb_array" if RECORD_VIDEO else None)])
vec_env = VecMonitor(base_env)

if RECORD_VIDEO:
    os.makedirs(VIDEO_DIR, exist_ok=True)

    def video_trigger(step_count: int) -> bool:
        return (step_count == 0) or (step_count % VIDEO_EVERY_N_STEPS == 0)

    vec_env = VecVideoRecorder(
        vec_env,
        video_folder=VIDEO_DIR,
        record_video_trigger=video_trigger,
        video_length=VIDEO_LENGTH,
        name_prefix="ppo_hip_knee_repeat_hops"
    )

# -------------------- 3) Train PPO --------------------
model = PPO(
    policy="MlpPolicy",
    env=vec_env,
    n_steps=1024,
    batch_size=256,
    gae_lambda=0.95,
    gamma=0.99,
    n_epochs=10,
    learning_rate=3e-4,
    clip_range=0.2,
    ent_coef=0.0,
    vf_coef=0.5,
    max_grad_norm=0.5,
    verbose=1,
    seed=SEED,
)

model.learn(total_timesteps=TOTAL_TIMESTEPS)
model.save(SAVE_PATH)
print(f"Saved trained policy to: {SAVE_PATH}")

vec_env.close()
print(f"Videos (if enabled) saved in: {VIDEO_DIR}")

# -------------------- 4) Evaluation with hop stats --------------------
eval_env = make_env(render_mode=None)
best_repeatable = -np.inf

for ep in range(10):
    obs, _ = eval_env.reset(seed=SEED + ep)
    done = False
    last_info = None
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)
        done = terminated or truncated
        last_info = info

    apex_heights = last_info["apex_heights"]
    if len(apex_heights) >= MIN_HOPS_FOR_SCORE:
        recent = apex_heights[-APEX_WINDOW:]
        repeatable = float(np.min(recent))
        best_repeatable = max(best_repeatable, repeatable)
        print(f"Episode {ep+1}: apex_count={len(apex_heights)} repeatable_h(min last {APEX_WINDOW})={repeatable:.4f}  recent={np.round(recent,4)}")
    else:
        print(f"Episode {ep+1}: apex_count={len(apex_heights)} (not enough hops to score)")

print(f"Best repeatable height over 10 eval episodes: {best_repeatable:.4f}")

eval_env.close()
# Out:
# === SANITY CHECK ===
# step=   0 | z=-0.0073 | vz=-0.6992 | L= 0.2114 | F=   0.25 | hip_u= 0.000 | knee_u= 1.000 | ncon=0 | apex=0 | apex_count=0 | repeatable_h=0.0000
# step=  50 | z=-0.0650 | vz=-0.5275 | L= 0.2137 | F=   1.40 | hip_u=-0.000 | knee_u= 1.000 | ncon=0 | apex=0 | apex_count=4 | repeatable_h=-0.0566
# Sanity check done.
#
# Using cpu device
# Saving video to g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_hip_knee_repeat_hops-step-0-to-step-1000.mp4
# MoviePy - Building video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_hip_knee_repeat_hops-step-0-to-step-1000.mp4.
# MoviePy - Writing video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_hip_knee_repeat_hops-step-0-to-step-1000.mp4
# MoviePy - Done !
# MoviePy - video ready g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_hip_knee_repeat_hops-step-0-to-step-1000.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -19.6    |
# | time/              |          |
# |    fps             | 39       |
# |    iterations      | 1        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -20.2       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.004810926 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -1.03       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.37        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00381    |
# |    std                  | 0.999       |
# |    value_loss           | 5.18        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 3            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0031350604 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0857      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.35         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00316     |
# |    std                  | 0.999        |
# |    value_loss           | 5.32         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -21          |
# | time/                   |              |
# |    fps                  | 86           |
# |    iterations           | 4            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0037906072 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.108       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00327     |
# |    std                  | 1            |
# |    value_loss           | 5.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -21.2        |
# | time/                   |              |
# |    fps                  | 88           |
# |    iterations           | 5            |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0042509357 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.138       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00251     |
# |    std                  | 1            |
# |    value_loss           | 6.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -21.4        |
# | time/                   |              |
# |    fps                  | 93           |
# |    iterations           | 6            |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0061893533 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.265       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00717     |
# |    std                  | 1            |
# |    value_loss           | 5.32         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -21          |
# | time/                   |              |
# |    fps                  | 98           |
# |    iterations           | 7            |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0016313866 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.579       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.15         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00209     |
# |    std                  | 1            |
# |    value_loss           | 5.14         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -20.8       |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 8           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004980139 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -0.574      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00574    |
# |    std                  | 1           |
# |    value_loss           | 3.42        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -20.7        |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 9            |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0044156937 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.778       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0042      |
# |    std                  | 0.999        |
# |    value_loss           | 3.83         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -20.2        |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 10           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0065099606 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.949       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00455     |
# |    std                  | 0.997        |
# |    value_loss           | 3.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -20          |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 11           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0034653826 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.508       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.995        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0025      |
# |    std                  | 0.996        |
# |    value_loss           | 2.8          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -19.8        |
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 12           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0047831316 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.069       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.843        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00452     |
# |    std                  | 0.993        |
# |    value_loss           | 2.51         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -19.8        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 13           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0057314816 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.0865       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.552        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00489     |
# |    std                  | 0.99         |
# |    value_loss           | 1.63         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 14          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006146938 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.678       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00679    |
# |    std                  | 0.986       |
# |    value_loss           | 1.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -19.8       |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 15          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.005584324 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.532       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00628    |
# |    std                  | 0.978       |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -19.7       |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 16          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006960312 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.456       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.976       |
# |    value_loss           | 0.942       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -19.6        |
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 17           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0043295845 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.813        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00631     |
# |    std                  | 0.973        |
# |    value_loss           | 1.87         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 18          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005122513 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.315       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00797    |
# |    std                  | 0.971       |
# |    value_loss           | 0.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 19          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.006368486 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.601       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00792    |
# |    std                  | 0.968       |
# |    value_loss           | 1.24        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -18.4        |
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 20           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0066570565 |
# |    clip_fraction        | 0.0983       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.256        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0117      |
# |    std                  | 0.962        |
# |    value_loss           | 0.551        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -18.2       |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 21          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.006278632 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.195       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00693    |
# |    std                  | 0.958       |
# |    value_loss           | 0.546       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -18          |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 22           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0035626974 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.652        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.258        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00528     |
# |    std                  | 0.949        |
# |    value_loss           | 0.501        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -17.6       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 23          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.004960125 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.445       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00736    |
# |    std                  | 0.942       |
# |    value_loss           | 1.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -17.8       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 24          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007260085 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.326       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.94        |
# |    value_loss           | 0.78        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -17.7       |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 25          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.007909804 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.459       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00694    |
# |    std                  | 0.938       |
# |    value_loss           | 1.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -17.3       |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 26          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007805207 |
# |    clip_fraction        | 0.0612      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.648       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00645    |
# |    std                  | 0.938       |
# |    value_loss           | 1.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -16.9       |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 27          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.010077715 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.924       |
# |    value_loss           | 0.306       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 28          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006786586 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.304       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00802    |
# |    std                  | 0.919       |
# |    value_loss           | 0.652       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -16.3       |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 29          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.007115081 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.335       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.918       |
# |    value_loss           | 0.804       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -15.9       |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 30          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007241345 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00709    |
# |    std                  | 0.919       |
# |    value_loss           | 0.356       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -15.5       |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 31          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.006127352 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.173       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00759    |
# |    std                  | 0.92        |
# |    value_loss           | 0.396       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -15.4        |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 32           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0066048773 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.65         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.263        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0071      |
# |    std                  | 0.915        |
# |    value_loss           | 0.646        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -15.2        |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 33           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0059603592 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.24         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00666     |
# |    std                  | 0.911        |
# |    value_loss           | 0.606        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -14.6        |
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 34           |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0047638165 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.242        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00662     |
# |    std                  | 0.907        |
# |    value_loss           | 0.504        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -14.3       |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 35          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.006690993 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.201       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00999    |
# |    std                  | 0.904       |
# |    value_loss           | 0.525       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -14.2        |
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 36           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0064353896 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.581        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.187        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00966     |
# |    std                  | 0.9          |
# |    value_loss           | 0.463        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -13.7       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 37          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.005668966 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.208       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00679    |
# |    std                  | 0.898       |
# |    value_loss           | 0.479       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -13.6       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 38          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005268665 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.174       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00797    |
# |    std                  | 0.898       |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -13.5       |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 39          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.005361877 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.276       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00689    |
# |    std                  | 0.896       |
# |    value_loss           | 0.536       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 40          |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006098722 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.544       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00775    |
# |    std                  | 0.896       |
# |    value_loss           | 1           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -13.3        |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 41           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0057532378 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.145        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00913     |
# |    std                  | 0.887        |
# |    value_loss           | 0.425        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -13.2        |
# | time/                   |              |
# |    fps                  | 128          |
# |    iterations           | 42           |
# |    time_elapsed         | 334          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0066115977 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.502        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.191        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00826     |
# |    std                  | 0.882        |
# |    value_loss           | 0.419        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -12.8       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 43          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.009442134 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.874       |
# |    value_loss           | 0.232       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | -12.6      |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 44         |
# |    time_elapsed         | 344        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00611052 |
# |    clip_fraction        | 0.0489     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.56      |
# |    explained_variance   | 0.627      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.16       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00777   |
# |    std                  | 0.87       |
# |    value_loss           | 0.38       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 150       |
# |    ep_rew_mean          | -12.3     |
# | time/                   |           |
# |    fps                  | 131       |
# |    iterations           | 45        |
# |    time_elapsed         | 349       |
# |    total_timesteps      | 46080     |
# | train/                  |           |
# |    approx_kl            | 0.0086827 |
# |    clip_fraction        | 0.0875    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.56     |
# |    explained_variance   | 0.779     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0752    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.012    |
# |    std                  | 0.867     |
# |    value_loss           | 0.167     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -12.1       |
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 46          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008055595 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0682      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00885    |
# |    std                  | 0.866       |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -11.8       |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 47          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.006818581 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.234       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00986    |
# |    std                  | 0.863       |
# |    value_loss           | 0.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -11.7       |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 48          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008886354 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0933      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.853       |
# |    value_loss           | 0.22        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -11.9        |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 49           |
# |    time_elapsed         | 373          |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0051397523 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0557       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00855     |
# |    std                  | 0.844        |
# |    value_loss           | 0.149        |
# ------------------------------------------
# Saving video to g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_hip_knee_repeat_hops-step-50000-to-step-51000.mp4
# MoviePy - Building video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_hip_knee_repeat_hops-step-50000-to-step-51000.mp4.
# MoviePy - Writing video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_hip_knee_repeat_hops-step-50000-to-step-51000.mp4
# MoviePy - Done !
# MoviePy - video ready g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_hip_knee_repeat_hops-step-50000-to-step-51000.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -11.8       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 50          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005344462 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00869    |
# |    std                  | 0.84        |
# |    value_loss           | 0.268       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -11.5        |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 51           |
# |    time_elapsed         | 399          |
# ...
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | -2.97      |
# | time/                   |            |
# |    fps                  | 153        |
# |    iterations           | 216        |
# |    time_elapsed         | 1440       |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.00647764 |
# |    clip_fraction        | 0.0676     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.72      |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0247    |
# |    n_updates            | 2150       |
# |    policy_gradient_loss | -0.00987   |
# |    std                  | 0.346      |
# |    value_loss           | 0.0124     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -2.91        |
# | time/                   |              |
# |    fps                  | 153          |
# |    iterations           | 217          |
# |    time_elapsed         | 1447         |
# |    total_timesteps      | 222208       |
# | train/                  |              |
# |    approx_kl            | 0.0077935234 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.709       |
# |    explained_variance   | 0.757        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0211      |
# |    n_updates            | 2160         |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.344        |
# |    value_loss           | 0.0134       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -2.79        |
# | time/                   |              |
# |    fps                  | 153          |
# |    iterations           | 218          |
# |    time_elapsed         | 1454         |
# |    total_timesteps      | 223232       |
# | train/                  |              |
# |    approx_kl            | 0.0101430435 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0183      |
# |    n_updates            | 2170         |
# |    policy_gradient_loss | -0.0161      |
# |    std                  | 0.342        |
# |    value_loss           | 0.0137       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -2.75        |
# | time/                   |              |
# |    fps                  | 153          |
# |    iterations           | 219          |
# |    time_elapsed         | 1459         |
# |    total_timesteps      | 224256       |
# | train/                  |              |
# |    approx_kl            | 0.0068142563 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.013       |
# |    n_updates            | 2180         |
# |    policy_gradient_loss | -0.00933     |
# |    std                  | 0.338        |
# |    value_loss           | 0.00776      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -2.7        |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 220         |
# |    time_elapsed         | 1464        |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.006481534 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.66       |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00564    |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.336       |
# |    value_loss           | 0.021       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -2.54       |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 221         |
# |    time_elapsed         | 1473        |
# |    total_timesteps      | 226304      |
# | train/                  |             |
# |    approx_kl            | 0.009546839 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 2200        |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.334       |
# |    value_loss           | 0.00892     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -2.48       |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 222         |
# |    time_elapsed         | 1479        |
# |    total_timesteps      | 227328      |
# | train/                  |             |
# |    approx_kl            | 0.011202861 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 2210        |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.331       |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -2.41       |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 223         |
# |    time_elapsed         | 1485        |
# |    total_timesteps      | 228352      |
# | train/                  |             |
# |    approx_kl            | 0.010577323 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.616      |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.014      |
# |    n_updates            | 2220        |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.328       |
# |    value_loss           | 0.00914     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -2.34       |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 224         |
# |    time_elapsed         | 1490        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.007544725 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00126    |
# |    n_updates            | 2230        |
# |    policy_gradient_loss | -0.00807    |
# |    std                  | 0.325       |
# |    value_loss           | 0.0256      |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 406
#     388 # -------------------- 3) Train PPO --------------------
#     389 model = PPO(
#     390     policy="MlpPolicy",
#     391     env=vec_env,
#    (...)
#     403     seed=SEED,
#     404 )
# --> 406 model.learn(total_timesteps=TOTAL_TIMESTEPS)
#     407 model.save(SAVE_PATH)
#     408 print(f"Saved trained policy to: {SAVE_PATH}")
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\stable_baselines3\ppo\ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)  # type: ignore[arg-type]
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\stable_baselines3\common\policies.py:647, in ActorCriticPolicy.forward(self, obs, deterministic)
#     645 features = self.extract_features(obs)
#     646 if self.share_features_extractor:
# --> 647     latent_pi, latent_vf = self.mlp_extractor(features)
#     648 else:
#     649     pi_features, vf_features = features
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\stable_baselines3\common\torch_layers.py:257, in MlpExtractor.forward(self, features)
#     252 def forward(self, features: th.Tensor) -> tuple[th.Tensor, th.Tensor]:
#     253     """
#     254     :return: latent_policy, latent_value of the specified network.
#     255         If all layers are shared, then ``latent_policy == latent_value``
#     256     """
# --> 257     return self.forward_actor(features), self.forward_critic(features)
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\stable_baselines3\common\torch_layers.py:263, in MlpExtractor.forward_critic(self, features)
#     262 def forward_critic(self, features: th.Tensor) -> th.Tensor:
# --> 263     return self.value_net(features)
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\robin\anaconda3\envs\mujoco_env\lib\site-packages\torch\nn\modules\activation.py:430, in Tanh.forward(self, input)
#     426 def forward(self, input: Tensor) -> Tensor:
#     427     """
#     428     Runs the forward pass.
#     429     """
# --> 430     return torch.tanh(input)
#
# KeyboardInterrupt:

# %%
import time
import numpy as np
import mujoco.viewer
from stable_baselines3 import PPO

# This 2nd cell is designed to work *directly* with your 1st cell:
# - Uses the same HipKneeRepeatHopEnv class (defined above)
# - Uses the same constants: SAVE_PATH, MODEL_XML_PATH, CTRL_HZ, MAX_HIP_CTRL, MAX_KNEE_CTRL, SEED, FLIP_TERMINATE_ANGLE
# - Runs indefinitely (episode_seconds=1e9) and resets on failure

def run_policy_continuous_viewer_paced(
    *,
    policy,
    xml_path: str,
    ctrl_hz: int,
    max_hip_ctrl: float,
    max_knee_ctrl: float,
    seed: int,
    flip_terminate_angle: float,
    speed: float = 0.25,          # 1.0 = real-time, 0.25 = 4x slower
    reset_on_failure: bool = True,
    print_every_seconds: float = 5.0,
    max_real_fps: float = 60.0,
):
    speed = float(max(1e-6, speed))

    # Use YOUR env class from cell 1
    env = HipKneeRepeatHopEnv(
        xml_path=xml_path,
        render_mode=None,          # viewer handles visualization directly
        episode_seconds=1e9,       # effectively "run forever"
        ctrl_hz=ctrl_hz,
        max_hip_ctrl=max_hip_ctrl,
        max_knee_ctrl=max_knee_ctrl,
        seed=seed,
    )

    try:
        obs, _ = env.reset(seed=seed)

        ctrl_step = 0
        sim_dt_per_ctrl = 1.0 / float(ctrl_hz)

        # Real-time pacing (slow down or speed up the wall-clock)
        target_real_dt_per_ctrl = sim_dt_per_ctrl / speed
        min_real_dt = 1.0 / float(max_real_fps)
        target_real_dt_per_ctrl = max(target_real_dt_per_ctrl, min_real_dt)

        print_every = max(1, int(round(print_every_seconds * ctrl_hz)))

        with mujoco.viewer.launch_passive(env.model, env.data) as viewer:
            while viewer.is_running():
                loop_t0 = time.perf_counter()

                action, _ = policy.predict(obs, deterministic=True)
                obs, reward, terminated, truncated, info = env.step(action)
                ctrl_step += 1

                viewer.sync()

                if (ctrl_step % print_every) == 0:
                    print(
                        f"ctrl={ctrl_step:7d} | z={info.get('root_z', float('nan')):+.4f} | "
                        f"vz={info.get('root_vz', float('nan')):+.4f} | "
                        f"ncon={info.get('ncon', -1)} | apex_cnt={info.get('apex_count', -1)} | "
                        f"repeat_h={info.get('repeatable_h', float('nan')):.4f} | "
                        f"std={info.get('std_recent', float('nan')):.4f} | "
                        f"hip_u={info.get('hip_u', float('nan')):+.3f} | "
                        f"knee_u={info.get('knee_u', float('nan')):+.3f}"
                    )

                # Reset conditions (terminated OR truncated, though truncated shouldn't happen with 1e9)
                if terminated or truncated:
                    # Try to infer a useful reason (matches logic in your env.step)
                    hip_q, _ = env._get_hip_q_qd()
                    root_z = info.get("root_z", np.nan)
                    root_vz = info.get("root_vz", np.nan)

                    reason = "terminated" if terminated else "truncated"
                    if (not np.isfinite(root_z)) or (not np.isfinite(root_vz)):
                        reason = "NaN/Inf state"
                    elif root_z < -1.5:
                        reason = "fell below z < -1.5"
                    elif abs(hip_q) > flip_terminate_angle:
                        reason = f"hip angle blew up |hip_q|={abs(hip_q):.3f} > {flip_terminate_angle:.3f}"

                    print(f"[RESET] {reason} at ctrl={ctrl_step}")

                    if reset_on_failure:
                        obs, _ = env.reset()
                        ctrl_step = 0
                    else:
                        break

                # Wall-clock pacing
                elapsed = time.perf_counter() - loop_t0
                sleep_for = target_real_dt_per_ctrl - elapsed
                if sleep_for > 0:
                    time.sleep(sleep_for)

    finally:
        env.close()


# ---- usage: assumes cell 1 already ran and produced these names ----
# SAVE_PATH, MODEL_XML_PATH, CTRL_HZ, MAX_HIP_CTRL, MAX_KNEE_CTRL, SEED, FLIP_TERMINATE_ANGLE
policy = PPO.load(SAVE_PATH)

run_policy_continuous_viewer_paced(
    policy=policy,
    xml_path=MODEL_XML_PATH,
    ctrl_hz=CTRL_HZ,
    max_hip_ctrl=MAX_HIP_CTRL,
    max_knee_ctrl=MAX_KNEE_CTRL,
    seed=SEED,
    flip_terminate_angle=FLIP_TERMINATE_ANGLE,
    speed=0.2,
)

# %%
# Standalone RL training cell for YOUR model (leg_hopper.xml)
# - TWO-DOF actuation: hip_motor + knee_motor controlled by the policy
# - Passive tendon spring: F = k*(L-L0) when L>L0 else 0
# - Reward = forward hopping: make progress in +x while maintaining hopping/airtime and reasonable height
#
# Requirements:
#   pip install mujoco gymnasium stable-baselines3 numpy imageio imageio-ffmpeg

import os
import numpy as npF
import mujoco
import gymnasium as gym
from gymnasium import spaces

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor, VecVideoRecorder


# ------------------------- USER SETTINGS -------------------------
MODEL_XML_PATH = "leg_hopper.xml"

# Joint/actuator names in your XML
HIP_JOINT_NAME       = "hip_joint"
KNEE_JOINT_NAME      = "knee_joint"
HIP_MOTOR_NAME       = "hip_motor"
KNEE_MOTOR_NAME      = "knee_motor"
TENDON_NAME          = "leg_spring"
TENDON_ACT_NAME      = "leg_spring_actuator"

# Root slider joints (in your XML)
ROOT_X_JOINT_NAME    = "hip_linear_x"
ROOT_Z_JOINT_NAME    = "hip_linear_z"

# Tendon spring parameters (your values)
SPRING_K  = 500.0       # N/m
SPRING_L0 = 0.2109      # m

# Action scaling (must respect each actuator ctrlrange in XML)
MAX_HIP_CTRL  = 2.0
MAX_KNEE_CTRL = 2.0

# Env timing
SEED = 0
CTRL_HZ = 50
EPISODE_SECONDS = 4.0    # give it a bit more time to build a gait

# Forward hopping reward settings
FORWARD_W = 2.0            # reward weight on forward progress per step (dx)
AIRTIME_W = 0.2            # reward for being airborne (ncon==0)
HEIGHT_W  = 0.05           # small shaping toward being above ground
BACKWARD_PEN = 4.0         # penalize negative dx harder
SIDEWAYS_VX_PEN = 0.01     # penalize very high vx (keeps things sane)
CTRL_PEN = 1e-2            # control penalty (u^2)

# Optional hop event shaping (kept light)
APEX_BONUS_W = 0.2          # bonus each apex event (airborne peak)
MIN_Z_FOR_APEX = 0.02       # ignore tiny "apex" jiggles near ground

FLIP_TERMINATE_ANGLE = 2.2  # rad, safety termination if hip joint goes crazy

# PPO
TOTAL_TIMESTEPS = 400_000
SAVE_PATH = "ppo_forward_hops.zip"

# Video recording
RECORD_VIDEO = True
VIDEO_DIR = "videos"
VIDEO_EVERY_N_STEPS = 50_000
VIDEO_SECONDS = 20.0
VIDEO_LENGTH = int(VIDEO_SECONDS * CTRL_HZ)

# ---------------------------------------------------------------


def _name2id_or_raise(model, obj_type, name: str) -> int:
    idx = mujoco.mj_name2id(model, obj_type, name)
    if idx < 0:
        raise ValueError(f"Name not found: {name} (type={obj_type})")
    return int(idx)

def _joint_qposadr(model, joint_id: int) -> int:
    return int(model.jnt_qposadr[joint_id])

def _joint_dofadr(model, joint_id: int) -> int:
    return int(model.jnt_dofadr[joint_id])


class ForwardHopEnv(gym.Env):
    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 50}

    def __init__(
        self,
        xml_path: str,
        render_mode: str | None = None,
        episode_seconds: float = 4.0,
        ctrl_hz: int = 50,
        max_hip_ctrl: float = 1.0,
        max_knee_ctrl: float = 1.0,
        seed: int = 0,
    ):
        super().__init__()

        if not os.path.exists(xml_path):
            raise FileNotFoundError(f"MuJoCo XML not found: {xml_path}")

        self.model = mujoco.MjModel.from_xml_path(xml_path)
        self.data = mujoco.MjData(self.model)

        # IDs
        self.hip_jid   = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_JOINT, HIP_JOINT_NAME)
        self.knee_jid  = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_JOINT, KNEE_JOINT_NAME)
        self.rootx_jid = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_JOINT, ROOT_X_JOINT_NAME)
        self.rootz_jid = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_JOINT, ROOT_Z_JOINT_NAME)

        self.hip_aid   = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_ACTUATOR, HIP_MOTOR_NAME)
        self.knee_aid  = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_ACTUATOR, KNEE_MOTOR_NAME)

        self.tendon_id  = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_TENDON, TENDON_NAME)
        self.tendon_aid = _name2id_or_raise(self.model, mujoco.mjtObj.mjOBJ_ACTUATOR, TENDON_ACT_NAME)

        # Addresses
        self.hip_qpos_adr   = _joint_qposadr(self.model, self.hip_jid)
        self.hip_dof_adr    = _joint_dofadr(self.model, self.hip_jid)
        self.knee_qpos_adr  = _joint_qposadr(self.model, self.knee_jid)
        self.knee_dof_adr   = _joint_dofadr(self.model, self.knee_jid)

        self.rootx_qpos_adr = _joint_qposadr(self.model, self.rootx_jid)
        self.rootx_dof_adr  = _joint_dofadr(self.model, self.rootx_jid)
        self.rootz_qpos_adr = _joint_qposadr(self.model, self.rootz_jid)
        self.rootz_dof_adr  = _joint_dofadr(self.model, self.rootz_jid)

        # Timing
        self.episode_seconds = float(episode_seconds)
        self.ctrl_hz = int(ctrl_hz)
        self.ctrl_dt = 1.0 / self.ctrl_hz
        self.sim_dt = float(self.model.opt.timestep)
        self.substeps = max(1, int(round(self.ctrl_dt / self.sim_dt)))

        self.max_hip_ctrl  = float(max_hip_ctrl)
        self.max_knee_ctrl = float(max_knee_ctrl)
        self.render_mode = render_mode
        self.np_random, _ = gym.utils.seeding.np_random(seed)

        self.horizon_steps = int(round(self.episode_seconds * self.ctrl_hz))
        self.t = 0

        # Bookkeeping for progress + apex detection
        self._prev_x = 0.0
        self._prev_vz = 0.0
        self._apex_count = 0

        # Spaces
        # obs: [hip_q, hip_qd, knee_q, knee_qd, x, vx, z, vz, tendon_L, ncon, phase]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(11,), dtype=np.float32)
        # action: [hip_u, knee_u] in [-1, 1] each (scaled)
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(2,), dtype=np.float32)

        self._renderer = None

    # ------------------ state helpers ------------------
    def _get_root_x_vx(self) -> tuple[float, float]:
        x  = float(self.data.qpos[self.rootx_qpos_adr])
        vx = float(self.data.qvel[self.rootx_dof_adr])
        return x, vx

    def _get_root_z_vz(self) -> tuple[float, float]:
        z  = float(self.data.qpos[self.rootz_qpos_adr])
        vz = float(self.data.qvel[self.rootz_dof_adr])
        return z, vz

    def _get_knee_q_qd(self) -> tuple[float, float]:
        return float(self.data.qpos[self.knee_qpos_adr]), float(self.data.qvel[self.knee_dof_adr])

    def _get_hip_q_qd(self) -> tuple[float, float]:
        return float(self.data.qpos[self.hip_qpos_adr]), float(self.data.qvel[self.hip_dof_adr])

    def _get_tendon_length(self) -> float:
        return float(self.data.ten_length[self.tendon_id])

    def _get_obs(self) -> np.ndarray:
        hip_q, hip_qd = self._get_hip_q_qd()
        knee_q, knee_qd = self._get_knee_q_qd()
        x, vx = self._get_root_x_vx()
        z, vz = self._get_root_z_vz()
        L = self._get_tendon_length()
        ncon = float(self.data.ncon)
        phase = float(self.t) / float(max(1, self.horizon_steps))
        return np.array([hip_q, hip_qd, knee_q, knee_qd, x, vx, z, vz, L, ncon, phase], dtype=np.float32)

    # ------------------ tendon spring ------------------
    def _apply_tendon_spring_force(self):
        L = float(self.data.ten_length[self.tendon_id])
        F = SPRING_K * (L - SPRING_L0) if L > SPRING_L0 else 0.0
        self.data.ctrl[self.tendon_aid] = float(F)
        return L, float(F)

    # ------------------ apex event detection ------------------
    def _detect_apex_event(self, z: float, vz: float, ncon: int) -> bool:
        # apex while airborne and vertical velocity crosses + -> -
        apex = (ncon == 0) and (self._prev_vz > 0.0) and (vz <= 0.0) and (z > MIN_Z_FOR_APEX)
        self._prev_vz = vz
        if apex:
            self._apex_count += 1
        return apex

    # ------------------ gym API ------------------
    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        if seed is not None:
            self.np_random, _ = gym.utils.seeding.np_random(seed)

        mujoco.mj_resetData(self.model, self.data)

        # Root start
        self.data.qpos[self.rootx_qpos_adr] = 0.0
        self.data.qvel[self.rootx_dof_adr]  = 0.0
        self.data.qpos[self.rootz_qpos_adr] = 0.0
        self.data.qvel[self.rootz_dof_adr]  = 0.0

        # Mild randomization on joints
        self.data.qpos[self.hip_qpos_adr]  += self.np_random.uniform(-0.05, 0.05)
        self.data.qvel[self.hip_dof_adr]   += self.np_random.uniform(-0.2, 0.2)
        self.data.qpos[self.knee_qpos_adr] += self.np_random.uniform(-0.05, 0.05)
        self.data.qvel[self.knee_dof_adr]  += self.np_random.uniform(-0.2, 0.2)

        mujoco.mj_forward(self.model, self.data)

        self.t = 0
        x, _ = self._get_root_x_vx()
        z, vz = self._get_root_z_vz()
        self._prev_x = x
        self._prev_vz = vz
        self._apex_count = 0

        return self._get_obs(), {}

    def step(self, action):
        self.t += 1
        self.data.ctrl[:] = 0.0

        # Tendon spring
        L, F = self._apply_tendon_spring_force()

        # Policy actions
        hip_u  = float(np.clip(action[0], -1.0, 1.0)) * self.max_hip_ctrl
        knee_u = float(np.clip(action[1], -1.0, 1.0)) * self.max_knee_ctrl
        self.data.ctrl[self.hip_aid]  = hip_u
        self.data.ctrl[self.knee_aid] = knee_u

        # Physics
        for _ in range(self.substeps):
            mujoco.mj_step(self.model, self.data)

        # State
        x, vx = self._get_root_x_vx()
        z, vz = self._get_root_z_vz()
        ncon = int(self.data.ncon)

        # Progress
        dx = float(x - self._prev_x)
        self._prev_x = x

        # Reward
        reward = 0.0

        # Forward progress (primary)
        if dx >= 0.0:
            reward += FORWARD_W * dx
        else:
            reward += -BACKWARD_PEN * abs(dx)

        # Encourage actual hopping (airtime) lightly
        if ncon == 0:
            reward += AIRTIME_W * (1.0 / self.ctrl_hz)

        # Small height shaping to avoid face-plant "sliding"
        reward += HEIGHT_W * float(z)

        # Apex bonus (optional, light)
        apex = self._detect_apex_event(z, vz, ncon)
        if apex:
            reward += APEX_BONUS_W

        # Keep vx from exploding
        reward -= SIDEWAYS_VX_PEN * float(vx * vx)

        # Control penalty
        reward -= CTRL_PEN * (hip_u * hip_u + knee_u * knee_u)

        # Termination / truncation
        truncated = (self.t >= self.horizon_steps)
        terminated = False

        # Safety: NaNs or extreme fall
        if not np.isfinite(x) or not np.isfinite(z) or not np.isfinite(vx) or not np.isfinite(vz):
            terminated = True
        if z < -1.5:
            terminated = True

        # Extra safety: hip joint shouldn't blow up
        hip_q, _ = self._get_hip_q_qd()
        if abs(hip_q) > FLIP_TERMINATE_ANGLE:
            terminated = True

        info = {
            "root_x": x,
            "root_vx": vx,
            "root_z": z,
            "root_vz": vz,
            "dx": dx,
            "tendon_L": L,
            "tendon_F": F,
            "hip_u": hip_u,
            "knee_u": knee_u,
            "ncon": ncon,
            "apex": bool(apex),
            "apex_count": int(self._apex_count),
        }

        return self._get_obs(), float(reward), terminated, truncated, info

    # ---- Rendering for VecVideoRecorder ----
    def render(self):
        if self.render_mode is None:
            return None
        if self.render_mode == "rgb_array":
            if self._renderer is None:
                self._renderer = mujoco.Renderer(self.model, height=480, width=640)
            self._renderer.update_scene(self.data, camera="close_cam")
            return self._renderer.render()
        if self.render_mode == "human":
            return None
        raise ValueError(f"Unknown render_mode: {self.render_mode}")

    def close(self):
        if self._renderer is not None:
            try:
                self._renderer.close()
            except Exception:
                pass
            self._renderer = None


# -------------------- Sanity check --------------------
def sanity_check(xml_path: str, steps: int = 300):
    print("=== SANITY CHECK ===")
    env = ForwardHopEnv(
        xml_path=xml_path,
        render_mode=None,
        episode_seconds=2.0,
        ctrl_hz=CTRL_HZ,
        max_hip_ctrl=MAX_HIP_CTRL,
        max_knee_ctrl=MAX_KNEE_CTRL,
        seed=SEED
    )
    obs, _ = env.reset(seed=SEED)

    # open-loop with a phase offset to induce fore-aft asymmetry
    f = 2.0
    A = 0.6
    for i in range(steps):
        t = i / CTRL_HZ
        hip_u  = A * np.sin(2*np.pi*f*t + 0.3)
        knee_u = A * np.sin(2*np.pi*f*t)
        obs, rew, terminated, truncated, info = env.step(np.array([hip_u, knee_u], dtype=np.float32))

        if i % 50 == 0:
            print(
                f"step={i:4d} | x={info['root_x']:7.4f} | vx={info['root_vx']:7.4f} | "
                f"z={info['root_z']:7.4f} | vz={info['root_vz']:7.4f} | dx={info['dx']: .5f} | "
                f"L={info['tendon_L']:7.4f} | F={info['tendon_F']:7.2f} | "
                f"hip_u={info['hip_u']:6.3f} | knee_u={info['knee_u']:6.3f} | ncon={info['ncon']} | "
                f"apex_count={info['apex_count']}"
            )

        if terminated or truncated:
            break

    env.close()
    print("Sanity check done.\n")


def make_env(render_mode=None):
    return ForwardHopEnv(
        xml_path=MODEL_XML_PATH,
        render_mode=render_mode,
        episode_seconds=EPISODE_SECONDS,
        ctrl_hz=CTRL_HZ,
        max_hip_ctrl=MAX_HIP_CTRL,
        max_knee_ctrl=MAX_KNEE_CTRL,
        seed=SEED,
    )


# -------------------- 1) Sanity check --------------------
sanity_check(MODEL_XML_PATH, steps=300)

# -------------------- 2) Vector env + video --------------------
base_env = DummyVecEnv([lambda: make_env(render_mode="rgb_array" if RECORD_VIDEO else None)])
vec_env = VecMonitor(base_env)

if RECORD_VIDEO:
    os.makedirs(VIDEO_DIR, exist_ok=True)

    def video_trigger(step_count: int) -> bool:
        return (step_count == 0) or (step_count % VIDEO_EVERY_N_STEPS == 0)

    vec_env = VecVideoRecorder(
        vec_env,
        video_folder=VIDEO_DIR,
        record_video_trigger=video_trigger,
        video_length=VIDEO_LENGTH,
        name_prefix="ppo_forward_hops"
    )

# -------------------- 3) Train PPO --------------------
model = PPO(
    policy="MlpPolicy",
    env=vec_env,
    n_steps=1024,
    batch_size=256,
    gae_lambda=0.95,
    gamma=0.99,
    n_epochs=10,
    learning_rate=3e-4,
    clip_range=0.2,
    ent_coef=0.0,
    vf_coef=0.5,
    max_grad_norm=0.5,
    verbose=1,
    seed=SEED,
)

model.learn(total_timesteps=TOTAL_TIMESTEPS)
model.save(SAVE_PATH)
print(f"Saved trained policy to: {SAVE_PATH}")

vec_env.close()
print(f"Videos (if enabled) saved in: {VIDEO_DIR}")

# -------------------- 4) Evaluation with forward stats --------------------
eval_env = make_env(render_mode=None)

best_distance = -np.inf
best_speed = -np.inf

for ep in range(10):
    obs, _ = eval_env.reset(seed=SEED + ep)
    done = False
    last_info = None
    x0 = float(eval_env.data.qpos[eval_env.rootx_qpos_adr])

    steps = 0
    apex_ct = 0
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)
        done = terminated or truncated
        last_info = info
        steps += 1
        apex_ct = info["apex_count"]

    x1 = float(last_info["root_x"])
    dist = float(x1 - x0)
    duration = steps / float(CTRL_HZ)
    speed = dist / max(1e-9, duration)

    best_distance = max(best_distance, dist)
    best_speed = max(best_speed, speed)

    print(f"Episode {ep+1}: dist={dist:.4f} m | avg_speed={speed:.4f} m/s | apex_count={apex_ct} | final_z={last_info['root_z']:.4f}")

print(f"Best distance over 10 eval episodes: {best_distance:.4f} m")
print(f"Best avg speed over 10 eval episodes: {best_speed:.4f} m/s")

eval_env.close()
# Out:
# === SANITY CHECK ===
# step=   0 | x= 0.0018 | vx= 0.1707 | z=-0.0009 | vz=-0.0967 | dx= 0.00176 | L= 0.2114 | F=   0.25 | hip_u= 0.355 | knee_u= 0.000 | ncon=0 | apex_count=0
# step=  50 | x=-0.8726 | vx=-1.5668 | z=-0.0909 | vz=-0.2011 | dx=-0.03321 | L= 0.2256 | F=   7.36 | hip_u= 0.355 | knee_u=-0.000 | ncon=0 | apex_count=0
# Sanity check done.
#
# Using cpu device
# Saving video to g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-0-to-step-1000.mp4
# MoviePy - Building video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-0-to-step-1000.mp4.
# MoviePy - Writing video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-0-to-step-1000.mp4
# MoviePy - Done !
# MoviePy - video ready g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-0-to-step-1000.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -12.3    |
# | time/              |          |
# |    fps             | 48       |
# |    iterations      | 1        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -11.5        |
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 2            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0048388382 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -2.97        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.588        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00597     |
# |    std                  | 1            |
# |    value_loss           | 1.62         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -11.8       |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 3           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.005772275 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | -0.0865     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.42        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00748    |
# |    std                  | 1           |
# |    value_loss           | 1.07        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -11.4        |
# | time/                   |              |
# |    fps                  | 97           |
# |    iterations           | 4            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036516546 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0612      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.343        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00445     |
# |    std                  | 0.994        |
# |    value_loss           | 0.857        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -11.2        |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 5            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0048594307 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.0175      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.245        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00539     |
# |    std                  | 0.988        |
# |    value_loss           | 0.671        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -11          |
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 6            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0037185077 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | -0.194       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.199        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00511     |
# |    std                  | 0.981        |
# |    value_loss           | 0.577        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -10.7        |
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 7            |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0058225268 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.091        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.19         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00874     |
# |    std                  | 0.977        |
# |    value_loss           | 0.504        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -10.4        |
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 8            |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0055838674 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00785     |
# |    std                  | 0.976        |
# |    value_loss           | 0.354        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -9.92        |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 9            |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0041002724 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0806       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00428     |
# |    std                  | 0.973        |
# |    value_loss           | 0.234        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -9.79        |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 10           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0052452735 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.552        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.062        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00837     |
# |    std                  | 0.971        |
# |    value_loss           | 0.151        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -9.54       |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 11          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.006653853 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0694      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00801    |
# |    std                  | 0.968       |
# |    value_loss           | 0.243       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -9.27        |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 12           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0066129738 |
# |    clip_fraction        | 0.0771       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0833       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.966        |
# |    value_loss           | 0.205        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -8.95        |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 13           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0050716824 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0571       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00815     |
# |    std                  | 0.958        |
# |    value_loss           | 0.171        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -8.63        |
# | time/                   |              |
# |    fps                  | 137          |
# |    iterations           | 14           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0034139156 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0678       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00613     |
# |    std                  | 0.953        |
# |    value_loss           | 0.185        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -8.45        |
# | time/                   |              |
# |    fps                  | 140          |
# |    iterations           | 15           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0059922505 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.422        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0556       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00843     |
# |    std                  | 0.947        |
# |    value_loss           | 0.142        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -8.14       |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 16          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009005275 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0489      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.943       |
# |    value_loss           | 0.153       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -7.82       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 17          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.009206978 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0334      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.937       |
# |    value_loss           | 0.132       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -7.55        |
# | time/                   |              |
# |    fps                  | 149          |
# |    iterations           | 18           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0057834024 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0552       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00682     |
# |    std                  | 0.933        |
# |    value_loss           | 0.147        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -7.37       |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 19          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.006516321 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0237      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00903    |
# |    std                  | 0.928       |
# |    value_loss           | 0.115       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -7.09       |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 20          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007698361 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0356      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.925       |
# |    value_loss           | 0.115       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -6.68       |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 21          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008218527 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0362      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.917       |
# |    value_loss           | 0.117       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -6.17      |
# | time/                   |            |
# |    fps                  | 154        |
# |    iterations           | 22         |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00688478 |
# |    clip_fraction        | 0.0374     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.65      |
# |    explained_variance   | 0.4        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0455     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00999   |
# |    std                  | 0.905      |
# |    value_loss           | 0.143      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -5.75        |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 23           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0096202465 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.419        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0216       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00938     |
# |    std                  | 0.899        |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -5.29        |
# | time/                   |              |
# |    fps                  | 154          |
# |    iterations           | 24           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0064524617 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.442        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00502      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.892        |
# |    value_loss           | 0.0855       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -4.76        |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 25           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0062128305 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0183       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.888        |
# |    value_loss           | 0.0821       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -4.34       |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 26          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010014448 |
# |    clip_fraction        | 0.0962      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.883       |
# |    value_loss           | 0.0644      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -4.01       |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 27          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.008699044 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00654     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.881       |
# |    value_loss           | 0.0691      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -3.77       |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 28          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012737947 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0394      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.876       |
# |    value_loss           | 0.0819      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -3.45        |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 29           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0074624307 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.483        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0165       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00985     |
# |    std                  | 0.868        |
# |    value_loss           | 0.0688       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -3.16        |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 30           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0068210503 |
# |    clip_fraction        | 0.0722       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0067       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 0.863        |
# |    value_loss           | 0.0627       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -2.78       |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 31          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.010236636 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0142      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.859       |
# |    value_loss           | 0.0543      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -2.59       |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 32          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007156548 |
# |    clip_fraction        | 0.0635      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0054      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.851       |
# |    value_loss           | 0.0468      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -2.42      |
# | time/                   |            |
# |    fps                  | 163        |
# |    iterations           | 33         |
# |    time_elapsed         | 207        |
# |    total_timesteps      | 33792      |
# | train/                  |            |
# |    approx_kl            | 0.00448586 |
# |    clip_fraction        | 0.0389     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.51      |
# |    explained_variance   | 0.512      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00986    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00908   |
# |    std                  | 0.847      |
# |    value_loss           | 0.0669     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -2.12       |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 34          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007922911 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.016       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.842       |
# |    value_loss           | 0.0571      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.93       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 35          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.007946375 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0049      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.834       |
# |    value_loss           | 0.0477      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.79       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 36          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009082712 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00679    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.827       |
# |    value_loss           | 0.0446      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.64       |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 37          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.007777988 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00914     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.823       |
# |    value_loss           | 0.0396      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.48       |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 38          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008927427 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0089      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.816       |
# |    value_loss           | 0.042       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.3        |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 39          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.008929568 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00529    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.809       |
# |    value_loss           | 0.0353      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.24        |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 40           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0071396665 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.393        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00674     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.805        |
# |    value_loss           | 0.04         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.07       |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 41          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.009774273 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.4        |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0355      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.8         |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.86       |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 42          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009106838 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.794       |
# |    value_loss           | 0.0521      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.795       |
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 43           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0089753205 |
# |    clip_fraction        | 0.0768       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0.471        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0113      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 0.79         |
# |    value_loss           | 0.0323       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.641      |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 44          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010163249 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00405    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.784       |
# |    value_loss           | 0.0539      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.527      |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 45          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.007293068 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00548    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.777       |
# |    value_loss           | 0.0397      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.43       |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 46          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005360609 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00271    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.77        |
# |    value_loss           | 0.0352      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.351      |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 47          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.007681405 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00341     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.765       |
# |    value_loss           | 0.0649      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.238      |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 48          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008267313 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.758       |
# |    value_loss           | 0.0707      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.161      |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 49          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.006994648 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00526    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.753       |
# |    value_loss           | 0.0398      |
# -----------------------------------------
# Saving video to g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-50000-to-step-51000.mp4
# MoviePy - Building video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-50000-to-step-51000.mp4.
# MoviePy - Writing video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-50000-to-step-51000.mp4
# MoviePy - Done !
# MoviePy - video ready g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-50000-to-step-51000.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -0.0303     |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 50          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012470712 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.747       |
# |    value_loss           | 0.0299      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 0.0357      |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 51          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 52224       |
# ...
# |    fps                  | 166        |
# |    iterations           | 376        |
# |    time_elapsed         | 2309       |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.03023139 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.57       |
# |    explained_variance   | 0.561      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0132    |
# |    n_updates            | 3750       |
# |    policy_gradient_loss | -0.00785   |
# |    std                  | 0.11       |
# |    value_loss           | 0.0132     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 377         |
# |    time_elapsed         | 2313        |
# |    total_timesteps      | 386048      |
# | train/                  |             |
# |    approx_kl            | 0.017535815 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.57        |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 3760        |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.11        |
# |    value_loss           | 0.009       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 378         |
# |    time_elapsed         | 2316        |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.011671737 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.58        |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0197     |
# |    n_updates            | 3770        |
# |    policy_gradient_loss | -0.00816    |
# |    std                  | 0.11        |
# |    value_loss           | 0.00687     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 15.3       |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 379        |
# |    time_elapsed         | 2320       |
# |    total_timesteps      | 388096     |
# | train/                  |            |
# |    approx_kl            | 0.02720853 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.59       |
# |    explained_variance   | 0.621      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00143    |
# |    n_updates            | 3780       |
# |    policy_gradient_loss | -0.00953   |
# |    std                  | 0.109      |
# |    value_loss           | 0.0115     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.4        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 380         |
# |    time_elapsed         | 2327        |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.013859691 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.6         |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0125     |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.0095     |
# |    std                  | 0.108       |
# |    value_loss           | 0.00769     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 15.4       |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 381        |
# |    time_elapsed         | 2335       |
# |    total_timesteps      | 390144     |
# | train/                  |            |
# |    approx_kl            | 0.01941774 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.61       |
# |    explained_variance   | 0.754      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00968    |
# |    n_updates            | 3800       |
# |    policy_gradient_loss | -0.00556   |
# |    std                  | 0.108      |
# |    value_loss           | 0.00595    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.4        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 382         |
# |    time_elapsed         | 2341        |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.014851727 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.62        |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00533    |
# |    n_updates            | 3810        |
# |    policy_gradient_loss | -0.00444    |
# |    std                  | 0.108       |
# |    value_loss           | 0.00856     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.4        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 383         |
# |    time_elapsed         | 2347        |
# |    total_timesteps      | 392192      |
# | train/                  |             |
# |    approx_kl            | 0.015819035 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.63        |
# |    explained_variance   | 0.565       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0013      |
# |    n_updates            | 3820        |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.107       |
# |    value_loss           | 0.0129      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.4        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 384         |
# |    time_elapsed         | 2351        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.014516365 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.64        |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00208    |
# |    n_updates            | 3830        |
# |    policy_gradient_loss | -0.00835    |
# |    std                  | 0.106       |
# |    value_loss           | 0.00941     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.4        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 385         |
# |    time_elapsed         | 2356        |
# |    total_timesteps      | 394240      |
# | train/                  |             |
# |    approx_kl            | 0.019779172 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.65        |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 3840        |
# |    policy_gradient_loss | 0.00252     |
# |    std                  | 0.106       |
# |    value_loss           | 0.00774     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 15.4       |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 386        |
# |    time_elapsed         | 2360       |
# |    total_timesteps      | 395264     |
# | train/                  |            |
# |    approx_kl            | 0.02235143 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.65       |
# |    explained_variance   | 0.68       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0019    |
# |    n_updates            | 3850       |
# |    policy_gradient_loss | -0.0119    |
# |    std                  | 0.106      |
# |    value_loss           | 0.0106     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.4        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 387         |
# |    time_elapsed         | 2366        |
# |    total_timesteps      | 396288      |
# | train/                  |             |
# |    approx_kl            | 0.018274896 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.66        |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 3860        |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.105       |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 388         |
# |    time_elapsed         | 2371        |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.014956725 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.67        |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0194     |
# |    n_updates            | 3870        |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.104       |
# |    value_loss           | 0.00759     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 389         |
# |    time_elapsed         | 2376        |
# |    total_timesteps      | 398336      |
# | train/                  |             |
# |    approx_kl            | 0.020186322 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.69        |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 3880        |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.104       |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 390         |
# |    time_elapsed         | 2380        |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.018197611 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.7         |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 3890        |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.103       |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 391         |
# |    time_elapsed         | 2389        |
# |    total_timesteps      | 400384      |
# | train/                  |             |
# |    approx_kl            | 0.028449554 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.71        |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 3900        |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.103       |
# |    value_loss           | 0.00849     |
# -----------------------------------------
# Saved trained policy to: ppo_forward_hops.zip
# MoviePy - Building video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-400000-to-step-401000.mp4.
# MoviePy - Writing video g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-400000-to-step-401000.mp4
# MoviePy - Done !
# MoviePy - video ready g:\My Drive\Study\Hopping_project\Optimization_Simulation\mujoco_leg_hopper\videos\ppo_forward_hops-step-400000-to-step-401000.mp4
# Videos (if enabled) saved in: videos
# Episode 1: dist=6.0023 m | avg_speed=1.5006 m/s | apex_count=60 | final_z=0.0323
# Episode 2: dist=6.0450 m | avg_speed=1.5113 m/s | apex_count=57 | final_z=0.0398
# Episode 3: dist=5.9663 m | avg_speed=1.4916 m/s | apex_count=58 | final_z=0.0458
# Episode 4: dist=5.9768 m | avg_speed=1.4942 m/s | apex_count=59 | final_z=0.0281
# Episode 5: dist=5.8577 m | avg_speed=1.4644 m/s | apex_count=61 | final_z=0.0305
# Episode 6: dist=5.9643 m | avg_speed=1.4911 m/s | apex_count=59 | final_z=0.0445
# Episode 7: dist=6.0182 m | avg_speed=1.5046 m/s | apex_count=59 | final_z=0.0447
# Episode 8: dist=5.6555 m | avg_speed=1.4139 m/s | apex_count=62 | final_z=0.0342
# Episode 9: dist=5.8791 m | avg_speed=1.4698 m/s | apex_count=60 | final_z=0.0350
# Episode 10: dist=5.8607 m | avg_speed=1.4652 m/s | apex_count=60 | final_z=0.0459
# Best distance over 10 eval episodes: 6.0450 m
# Best avg speed over 10 eval episodes: 1.5113 m/s

# %%
import time
import numpy as np
import mujoco.viewer
from stable_baselines3 import PPO

# This viewer cell is designed to work *directly* with your ForwardHopEnv training cell:
# - Uses the same ForwardHopEnv class (defined above)
# - Uses the same constants: SAVE_PATH, MODEL_XML_PATH, CTRL_HZ, MAX_HIP_CTRL, MAX_KNEE_CTRL, SEED, FLIP_TERMINATE_ANGLE
# - Runs indefinitely (episode_seconds=1e9) and resets on failure

def run_forward_policy_continuous_viewer_paced(
    *,
    policy,
    xml_path: str,
    ctrl_hz: int,
    max_hip_ctrl: float,
    max_knee_ctrl: float,
    seed: int,
    flip_terminate_angle: float,
    speed: float = 0.01,          # 1.0 = real-time, 0.25 = 4x slower
    reset_on_failure: bool = True,
    print_every_seconds: float = 5.0,
    max_real_fps: float = 100.0,
):
    speed = float(max(1e-6, speed))

    # Use YOUR env class from the forward-hopping cell
    env = ForwardHopEnv(
        xml_path=xml_path,
        render_mode=None,          # viewer handles visualization directly
        episode_seconds=1e9,       # effectively "run forever"
        ctrl_hz=ctrl_hz,
        max_hip_ctrl=max_hip_ctrl,
        max_knee_ctrl=max_knee_ctrl,
        seed=seed,
    )

    try:
        obs, _ = env.reset(seed=seed)

        ctrl_step = 0
        sim_dt_per_ctrl = 1.0 / float(ctrl_hz)

        # Real-time pacing (slow down or speed up the wall-clock)
        target_real_dt_per_ctrl = sim_dt_per_ctrl / speed
        min_real_dt = 1.0 / float(max_real_fps)
        target_real_dt_per_ctrl = max(target_real_dt_per_ctrl, min_real_dt)

        print_every = max(1, int(round(print_every_seconds * ctrl_hz)))

        with mujoco.viewer.launch_passive(env.model, env.data) as viewer:
            while viewer.is_running():
                loop_t0 = time.perf_counter()

                action, _ = policy.predict(obs, deterministic=True)
                obs, reward, terminated, truncated, info = env.step(action)
                ctrl_step += 1

                viewer.sync()

                if (ctrl_step % print_every) == 0:
                    # distance since last reset is tracked via env._prev_x logic; we can also just print current x
                    print(
                        f"ctrl={ctrl_step:7d} | x={info.get('root_x', float('nan')):+.4f} | "
                        f"vx={info.get('root_vx', float('nan')):+.4f} | "
                        f"z={info.get('root_z', float('nan')):+.4f} | "
                        f"vz={info.get('root_vz', float('nan')):+.4f} | "
                        f"dx={info.get('dx', float('nan')):+.5f} | "
                        f"ncon={info.get('ncon', -1)} | apex_cnt={info.get('apex_count', -1)} | "
                        f"hip_u={info.get('hip_u', float('nan')):+.3f} | "
                        f"knee_u={info.get('knee_u', float('nan')):+.3f} | "
                        f"L={info.get('tendon_L', float('nan')):.4f} | F={info.get('tendon_F', float('nan')):.2f}"
                    )

                # Reset conditions (terminated OR truncated, though truncated shouldn't happen with 1e9)
                if terminated or truncated:
                    # Try to infer a useful reason (matches logic in your env.step)
                    hip_q, _ = env._get_hip_q_qd()
                    root_x = info.get("root_x", np.nan)
                    root_z = info.get("root_z", np.nan)
                    root_vx = info.get("root_vx", np.nan)
                    root_vz = info.get("root_vz", np.nan)

                    reason = "terminated" if terminated else "truncated"
                    if (not np.isfinite(root_x)) or (not np.isfinite(root_z)) or (not np.isfinite(root_vx)) or (not np.isfinite(root_vz)):
                        reason = "NaN/Inf state"
                    elif root_z < -1.5:
                        reason = "fell below z < -1.5"
                    elif abs(hip_q) > flip_terminate_angle:
                        reason = f"hip angle blew up |hip_q|={abs(hip_q):.3f} > {flip_terminate_angle:.3f}"

                    print(f"[RESET] {reason} at ctrl={ctrl_step}")

                    if reset_on_failure:
                        obs, _ = env.reset()
                        ctrl_step = 0
                    else:
                        break

                # Wall-clock pacing
                elapsed = time.perf_counter() - loop_t0
                sleep_for = target_real_dt_per_ctrl - elapsed
                if sleep_for > 0:
                    time.sleep(sleep_for)

    finally:
        env.close()


# ---- usage: assumes your forward-training cell already ran and produced these names ----
# SAVE_PATH, MODEL_XML_PATH, CTRL_HZ, MAX_HIP_CTRL, MAX_KNEE_CTRL, SEED, FLIP_TERMINATE_ANGLE
policy = PPO.load(SAVE_PATH)

run_forward_policy_continuous_viewer_paced(
    policy=policy,
    xml_path=MODEL_XML_PATH,
    ctrl_hz=CTRL_HZ,
    max_hip_ctrl=MAX_HIP_CTRL,
    max_knee_ctrl=MAX_KNEE_CTRL,
    seed=SEED,
    flip_terminate_angle=FLIP_TERMINATE_ANGLE,
    speed=0.05,
)
